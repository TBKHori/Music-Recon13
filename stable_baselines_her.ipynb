# %% [markdown]
# # Stable Baselines - Hindsight Experience Replay on Highway Env
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
# Highway env: [https://github.com/eleurent/highway-env](https://github.com/eleurent/highway-env)
#
# [RL Baselines3 Zoo](https://github.com/DLR-RM/rl-baselines3-zoo) is a training framework for Reinforcement Learning (RL), using Stable Baselines3.
#
# It provides scripts for training, evaluating agents, tuning hyperparameters, plotting results and recording videos.
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Install Dependencies and Stable Baselines Using Pip
#
#
# ```
# pip install stable-baselines3[extra]
# ```

# %%
# for autoformatting
# %load_ext jupyter_black

# %%
# Install stable-baselines latest version
# !pip install "stable-baselines3[extra]>=2.0.0a4"
# Out:
# Collecting stable-baselines3[extra]>=2.0.0a4
#   Downloading stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 kB 6.6 MB/s eta 0:00:00
# Collecting gymnasium==0.28.1 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 29.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (1.22.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.7.0.72)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.12.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (4.65.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (13.4.2)
# Collecting shimmy[atari]~=0.2.1 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (8.4.0)
# Collecting autorom[accept-rom-license]~=0.6.0 (from stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]>=2.0.0a4) (2.4.0)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a4)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a4) (4.6.3)
# Collecting farama-notifications>=0.0.1 (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a4)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (8.1.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (2.27.1)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4)
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 38.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=0.2.1->stable-baselines3[extra]>=2.0.0a4)
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 77.0 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.56.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.4.3)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.40.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (16.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]>=2.0.0a4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]>=2.0.0a4) (2022.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]>=2.0.0a4) (2.14.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=0.2.1->stable-baselines3[extra]>=2.0.0a4) (5.12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a4) (0.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.0->stable-baselines3[extra]>=2.0.0a4) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3[extra]>=2.0.0a4) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a4) (3.2.2)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=03083b1765711dd9b247360bcbcbc887cc65ba1ffd9d63824615e0cd7b55e919
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, jax-jumpy, ale-py, gymnasium, AutoROM.accept-rom-license, autorom, shimmy, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 gymnasium-0.28.1 jax-jumpy-1.0.0 shimmy-0.2.1 stable-baselines3-2.0.0

# %%
# Install highway-env
# !pip install highway-env
# Out:
# Collecting highway-env
#   Downloading highway_env-1.8.2-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.0/104.0 kB 5.0 MB/s eta 0:00:00
# Requirement already satisfied: gymnasium>=0.27 in /usr/local/lib/python3.10/dist-packages (from highway-env) (0.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from highway-env) (1.22.4)
# Requirement already satisfied: pygame>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from highway-env) (2.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from highway-env) (3.7.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from highway-env) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from highway-env) (1.10.1)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27->highway-env) (1.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27->highway-env) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27->highway-env) (4.6.3)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from gymnasium>=0.27->highway-env) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->highway-env) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->highway-env) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->highway-env) (1.16.0)
# Installing collected packages: highway-env
# Successfully installed highway-env-1.8.2

# %% [markdown]
# ## Import policy, RL agent, ...

# %%
import gymnasium as gym
import highway_env
import numpy as np

from stable_baselines3 import HerReplayBuffer, SAC, DDPG
from stable_baselines3.common.noise import NormalActionNoise
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# /usr/local/lib/python3.10/dist-packages/jaxlib/xla_client.py:225: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   float8_e4m3b11fnuz = ml_dtypes.float8_e4m3b11

# %% [markdown]
# ## Create the Gym env and instantiate the agent
#
# For this example, we will be using the parking environment from the [highway-env](https://github.com/Farama-Foundation/HighwayEnv) repo by @eleurent.
#
# The parking env is a goal-conditioned continuous control task, in which the vehicle must park in a given space with the appropriate heading.
#
#
# ![parking-env](https://raw.githubusercontent.com/eleurent/highway-env/gh-media/docs/media/parking-env.gif)

# %% [markdown]
# ### Train Soft Actor-Critic (SAC) agent
#
# Here, we use HER "future" goal sampling strategy, where we create 4 artificial transitions per real transition
#
# Note: the hyperparameters (network architecture, discount factor, ...) were tuned for this task

# %%
env = gym.make("parking-v0")

# %%
# SAC hyperparams:
model = SAC(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=4,
        goal_selection_strategy="future",
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_rate=1e-3,
    gamma=0.95,
    batch_size=256,
    policy_kwargs=dict(net_arch=[256, 256, 256]),
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train for 1e5 steps
model.learn(int(1e5))
# Save the trained agent
model.save('her_sac_highway')
# Out:
# Streaming output truncated to the last 5000 lines.
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 2212     |
# |    fps             | 37       |
# |    time_elapsed    | 2052     |
# |    total_timesteps | 77402    |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.0061   |
# |    ent_coef        | 0.00465  |
# |    ent_coef_loss   | -0.687   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77301    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | -7.09    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 2216     |
# |    fps             | 37       |
# |    time_elapsed    | 2054     |
# |    total_timesteps | 77475    |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.0062   |
# |    ent_coef        | 0.00471  |
# |    ent_coef_loss   | 0.433    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77374    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | -7.07    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 2220     |
# |    fps             | 37       |
# |    time_elapsed    | 2056     |
# |    total_timesteps | 77551    |
# | train/             |          |
# |    actor_loss      | 1.61     |
# |    critic_loss     | 0.00628  |
# |    ent_coef        | 0.00485  |
# |    ent_coef_loss   | -0.439   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77450    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | -6.8     |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 2224     |
# |    fps             | 37       |
# |    time_elapsed    | 2057     |
# |    total_timesteps | 77604    |
# | train/             |          |
# |    actor_loss      | 1.67     |
# |    critic_loss     | 0.0084   |
# |    ent_coef        | 0.00478  |
# |    ent_coef_loss   | 0.0364   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77503    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | -6.82    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2228     |
# |    fps             | 37       |
# |    time_elapsed    | 2059     |
# |    total_timesteps | 77686    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.00483  |
# |    ent_coef        | 0.00468  |
# |    ent_coef_loss   | 0.468    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77585    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | -6.83    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2232     |
# |    fps             | 37       |
# |    time_elapsed    | 2062     |
# |    total_timesteps | 77772    |
# | train/             |          |
# |    actor_loss      | 1.81     |
# |    critic_loss     | 0.00648  |
# |    ent_coef        | 0.00473  |
# |    ent_coef_loss   | 0.521    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77671    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | -7.03    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 2236     |
# |    fps             | 37       |
# |    time_elapsed    | 2065     |
# |    total_timesteps | 77878    |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 0.0234   |
# |    ent_coef        | 0.00469  |
# |    ent_coef_loss   | -1.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77777    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.14    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2240     |
# |    fps             | 37       |
# |    time_elapsed    | 2067     |
# |    total_timesteps | 77978    |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.00797  |
# |    ent_coef        | 0.00474  |
# |    ent_coef_loss   | -0.061   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77877    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.07    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 2244     |
# |    fps             | 37       |
# |    time_elapsed    | 2070     |
# |    total_timesteps | 78059    |
# | train/             |          |
# |    actor_loss      | 1.63     |
# |    critic_loss     | 0.00688  |
# |    ent_coef        | 0.00472  |
# |    ent_coef_loss   | 0.729    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 77958    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -7.1     |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2248     |
# |    fps             | 37       |
# |    time_elapsed    | 2071     |
# |    total_timesteps | 78133    |
# | train/             |          |
# |    actor_loss      | 1.73     |
# |    critic_loss     | 0.00582  |
# |    ent_coef        | 0.00473  |
# |    ent_coef_loss   | 0.853    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78032    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | -7.1     |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2252     |
# |    fps             | 37       |
# |    time_elapsed    | 2074     |
# |    total_timesteps | 78224    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.0182   |
# |    ent_coef        | 0.00486  |
# |    ent_coef_loss   | 0.594    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78123    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.16    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2256     |
# |    fps             | 37       |
# |    time_elapsed    | 2077     |
# |    total_timesteps | 78325    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.00565  |
# |    ent_coef        | 0.00489  |
# |    ent_coef_loss   | 0.518    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78224    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.18    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2260     |
# |    fps             | 37       |
# |    time_elapsed    | 2079     |
# |    total_timesteps | 78412    |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.00593  |
# |    ent_coef        | 0.00497  |
# |    ent_coef_loss   | 0.0288   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78311    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | -7.2     |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2264     |
# |    fps             | 37       |
# |    time_elapsed    | 2082     |
# |    total_timesteps | 78529    |
# | train/             |          |
# |    actor_loss      | 1.61     |
# |    critic_loss     | 0.00984  |
# |    ent_coef        | 0.005    |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78428    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | -7.32    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2268     |
# |    fps             | 37       |
# |    time_elapsed    | 2085     |
# |    total_timesteps | 78619    |
# | train/             |          |
# |    actor_loss      | 1.73     |
# |    critic_loss     | 0.00881  |
# |    ent_coef        | 0.005    |
# |    ent_coef_loss   | 0.528    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78518    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.34    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2272     |
# |    fps             | 37       |
# |    time_elapsed    | 2087     |
# |    total_timesteps | 78695    |
# | train/             |          |
# |    actor_loss      | 1.78     |
# |    critic_loss     | 0.00643  |
# |    ent_coef        | 0.00496  |
# |    ent_coef_loss   | 0.623    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78594    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | -7.45    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2276     |
# |    fps             | 37       |
# |    time_elapsed    | 2090     |
# |    total_timesteps | 78784    |
# | train/             |          |
# |    actor_loss      | 1.49     |
# |    critic_loss     | 0.0106   |
# |    ent_coef        | 0.00494  |
# |    ent_coef_loss   | -0.108   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78683    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -7.39    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2280     |
# |    fps             | 37       |
# |    time_elapsed    | 2092     |
# |    total_timesteps | 78864    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.00962  |
# |    ent_coef        | 0.00493  |
# |    ent_coef_loss   | 1.92     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78763    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.35    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2284     |
# |    fps             | 37       |
# |    time_elapsed    | 2094     |
# |    total_timesteps | 78940    |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 0.0247   |
# |    ent_coef        | 0.00504  |
# |    ent_coef_loss   | -0.493   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78839    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.3     |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2288     |
# |    fps             | 37       |
# |    time_elapsed    | 2096     |
# |    total_timesteps | 79018    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.0278   |
# |    ent_coef        | 0.00507  |
# |    ent_coef_loss   | 0.959    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78917    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | -7.36    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2292     |
# |    fps             | 37       |
# |    time_elapsed    | 2097     |
# |    total_timesteps | 79085    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.00842  |
# |    ent_coef        | 0.00505  |
# |    ent_coef_loss   | 0.817    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 78984    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.37    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2296     |
# |    fps             | 37       |
# |    time_elapsed    | 2101     |
# |    total_timesteps | 79186    |
# | train/             |          |
# |    actor_loss      | 1.48     |
# |    critic_loss     | 0.00475  |
# |    ent_coef        | 0.00512  |
# |    ent_coef_loss   | -1.62    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79085    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.27    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 37       |
# |    time_elapsed    | 2103     |
# |    total_timesteps | 79272    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.0164   |
# |    ent_coef        | 0.005    |
# |    ent_coef_loss   | -0.0443  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79171    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.35    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 2304     |
# |    fps             | 37       |
# |    time_elapsed    | 2105     |
# |    total_timesteps | 79343    |
# | train/             |          |
# |    actor_loss      | 1.62     |
# |    critic_loss     | 0.0141   |
# |    ent_coef        | 0.00504  |
# |    ent_coef_loss   | 0.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79242    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 2308     |
# |    fps             | 37       |
# |    time_elapsed    | 2106     |
# |    total_timesteps | 79402    |
# | train/             |          |
# |    actor_loss      | 1.74     |
# |    critic_loss     | 0.00726  |
# |    ent_coef        | 0.0051   |
# |    ent_coef_loss   | 0.438    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79301    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | -7.14    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2312     |
# |    fps             | 37       |
# |    time_elapsed    | 2108     |
# |    total_timesteps | 79488    |
# | train/             |          |
# |    actor_loss      | 1.51     |
# |    critic_loss     | 0.0101   |
# |    ent_coef        | 0.00512  |
# |    ent_coef_loss   | 0.541    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79387    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.1     |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2316     |
# |    fps             | 37       |
# |    time_elapsed    | 2111     |
# |    total_timesteps | 79559    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.00533  |
# |    ent_coef        | 0.00507  |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79458    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | -7.08    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2320     |
# |    fps             | 37       |
# |    time_elapsed    | 2113     |
# |    total_timesteps | 79637    |
# | train/             |          |
# |    actor_loss      | 1.43     |
# |    critic_loss     | 0.00575  |
# |    ent_coef        | 0.00508  |
# |    ent_coef_loss   | -1.45    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79536    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.1     |
# |    ep_rew_mean     | -7.19    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 2324     |
# |    fps             | 37       |
# |    time_elapsed    | 2115     |
# |    total_timesteps | 79712    |
# | train/             |          |
# |    actor_loss      | 1.5      |
# |    critic_loss     | 0.00836  |
# |    ent_coef        | 0.00522  |
# |    ent_coef_loss   | 0.015    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79611    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -7.12    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 2328     |
# |    fps             | 37       |
# |    time_elapsed    | 2117     |
# |    total_timesteps | 79785    |
# | train/             |          |
# |    actor_loss      | 1.72     |
# |    critic_loss     | 0.00533  |
# |    ent_coef        | 0.00526  |
# |    ent_coef_loss   | 0.0512   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79684    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21       |
# |    ep_rew_mean     | -7.13    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 2332     |
# |    fps             | 37       |
# |    time_elapsed    | 2119     |
# |    total_timesteps | 79876    |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.0313   |
# |    ent_coef        | 0.00517  |
# |    ent_coef_loss   | -0.374   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79775    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7       |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 2336     |
# |    fps             | 37       |
# |    time_elapsed    | 2122     |
# |    total_timesteps | 79957    |
# | train/             |          |
# |    actor_loss      | 1.43     |
# |    critic_loss     | 0.01     |
# |    ent_coef        | 0.00513  |
# |    ent_coef_loss   | -0.153   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79856    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -6.94    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2340     |
# |    fps             | 37       |
# |    time_elapsed    | 2125     |
# |    total_timesteps | 80046    |
# | train/             |          |
# |    actor_loss      | 1.49     |
# |    critic_loss     | 0.0266   |
# |    ent_coef        | 0.00519  |
# |    ent_coef_loss   | -0.742   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 79945    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | -6.93    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2344     |
# |    fps             | 37       |
# |    time_elapsed    | 2127     |
# |    total_timesteps | 80124    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.00592  |
# |    ent_coef        | 0.00517  |
# |    ent_coef_loss   | -0.0312  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80023    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -6.96    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2348     |
# |    fps             | 37       |
# |    time_elapsed    | 2129     |
# |    total_timesteps | 80212    |
# | train/             |          |
# |    actor_loss      | 1.48     |
# |    critic_loss     | 0.00721  |
# |    ent_coef        | 0.00514  |
# |    ent_coef_loss   | 0.291    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80111    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.2     |
# |    ep_rew_mean     | -7.01    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2352     |
# |    fps             | 37       |
# |    time_elapsed    | 2132     |
# |    total_timesteps | 80341    |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.00802  |
# |    ent_coef        | 0.00522  |
# |    ent_coef_loss   | -0.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80240    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -6.9     |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2356     |
# |    fps             | 37       |
# |    time_elapsed    | 2134     |
# |    total_timesteps | 80400    |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.00789  |
# |    ent_coef        | 0.00522  |
# |    ent_coef_loss   | 0.0185   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80299    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -6.88    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2360     |
# |    fps             | 37       |
# |    time_elapsed    | 2137     |
# |    total_timesteps | 80486    |
# | train/             |          |
# |    actor_loss      | 1.74     |
# |    critic_loss     | 0.0347   |
# |    ent_coef        | 0.00526  |
# |    ent_coef_loss   | 0.815    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80385    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | -6.85    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2364     |
# |    fps             | 37       |
# |    time_elapsed    | 2139     |
# |    total_timesteps | 80580    |
# | train/             |          |
# |    actor_loss      | 1.68     |
# |    critic_loss     | 0.00836  |
# |    ent_coef        | 0.00522  |
# |    ent_coef_loss   | 0.802    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80479    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -6.74    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2368     |
# |    fps             | 37       |
# |    time_elapsed    | 2141     |
# |    total_timesteps | 80659    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.00951  |
# |    ent_coef        | 0.00518  |
# |    ent_coef_loss   | 0.334    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80558    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -6.73    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2372     |
# |    fps             | 37       |
# |    time_elapsed    | 2143     |
# |    total_timesteps | 80733    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.0137   |
# |    ent_coef        | 0.00527  |
# |    ent_coef_loss   | -0.504   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80632    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -6.67    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2376     |
# |    fps             | 37       |
# |    time_elapsed    | 2145     |
# |    total_timesteps | 80805    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.0144   |
# |    ent_coef        | 0.00522  |
# |    ent_coef_loss   | 0.184    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80704    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -6.67    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2380     |
# |    fps             | 37       |
# |    time_elapsed    | 2147     |
# |    total_timesteps | 80892    |
# | train/             |          |
# |    actor_loss      | 1.42     |
# |    critic_loss     | 0.0194   |
# |    ent_coef        | 0.00522  |
# |    ent_coef_loss   | -1.19    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80791    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -6.77    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2384     |
# |    fps             | 37       |
# |    time_elapsed    | 2150     |
# |    total_timesteps | 80983    |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.00438  |
# |    ent_coef        | 0.00528  |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80882    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -6.8     |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2388     |
# |    fps             | 37       |
# |    time_elapsed    | 2152     |
# |    total_timesteps | 81058    |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.00598  |
# |    ent_coef        | 0.00533  |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 80957    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -6.88    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2392     |
# |    fps             | 37       |
# |    time_elapsed    | 2154     |
# |    total_timesteps | 81152    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.00997  |
# |    ent_coef        | 0.0052   |
# |    ent_coef_loss   | -0.618   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81051    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -6.83    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2396     |
# |    fps             | 37       |
# |    time_elapsed    | 2156     |
# |    total_timesteps | 81223    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.0191   |
# |    ent_coef        | 0.00517  |
# |    ent_coef_loss   | 0.408    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81122    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -6.77    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 37       |
# |    time_elapsed    | 2158     |
# |    total_timesteps | 81299    |
# | train/             |          |
# |    actor_loss      | 1.47     |
# |    critic_loss     | 0.00535  |
# |    ent_coef        | 0.00506  |
# |    ent_coef_loss   | -0.296   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81198    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -6.66    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2404     |
# |    fps             | 37       |
# |    time_elapsed    | 2160     |
# |    total_timesteps | 81367    |
# | train/             |          |
# |    actor_loss      | 1.43     |
# |    critic_loss     | 0.00378  |
# |    ent_coef        | 0.00511  |
# |    ent_coef_loss   | -0.409   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81266    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -6.73    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2408     |
# |    fps             | 37       |
# |    time_elapsed    | 2163     |
# |    total_timesteps | 81445    |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 0.0208   |
# |    ent_coef        | 0.00514  |
# |    ent_coef_loss   | -1.58    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81344    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -6.61    |
# |    success_rate    | 0.97     |
# | time/              |          |
# |    episodes        | 2412     |
# |    fps             | 37       |
# |    time_elapsed    | 2164     |
# |    total_timesteps | 81507    |
# | train/             |          |
# |    actor_loss      | 1.61     |
# |    critic_loss     | 0.00446  |
# |    ent_coef        | 0.00518  |
# |    ent_coef_loss   | -0.24    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81406    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -6.75    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2416     |
# |    fps             | 37       |
# |    time_elapsed    | 2166     |
# |    total_timesteps | 81586    |
# | train/             |          |
# |    actor_loss      | 1.42     |
# |    critic_loss     | 0.00544  |
# |    ent_coef        | 0.00525  |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81485    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | -6.75    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2420     |
# |    fps             | 37       |
# |    time_elapsed    | 2168     |
# |    total_timesteps | 81683    |
# | train/             |          |
# |    actor_loss      | 1.45     |
# |    critic_loss     | 0.00678  |
# |    ent_coef        | 0.00524  |
# |    ent_coef_loss   | -1.63    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81582    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | -6.76    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2424     |
# |    fps             | 37       |
# |    time_elapsed    | 2170     |
# |    total_timesteps | 81758    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.0224   |
# |    ent_coef        | 0.00518  |
# |    ent_coef_loss   | 0.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81657    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | -6.79    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2428     |
# |    fps             | 37       |
# |    time_elapsed    | 2172     |
# |    total_timesteps | 81835    |
# | train/             |          |
# |    actor_loss      | 1.64     |
# |    critic_loss     | 0.00764  |
# |    ent_coef        | 0.00504  |
# |    ent_coef_loss   | -0.696   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81734    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | -6.8     |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2432     |
# |    fps             | 37       |
# |    time_elapsed    | 2175     |
# |    total_timesteps | 81928    |
# | train/             |          |
# |    actor_loss      | 1.45     |
# |    critic_loss     | 0.00825  |
# |    ent_coef        | 0.00501  |
# |    ent_coef_loss   | -0.876   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81827    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -6.81    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2436     |
# |    fps             | 37       |
# |    time_elapsed    | 2178     |
# |    total_timesteps | 82025    |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.00596  |
# |    ent_coef        | 0.00514  |
# |    ent_coef_loss   | 0.354    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81924    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | -6.78    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2440     |
# |    fps             | 37       |
# |    time_elapsed    | 2180     |
# |    total_timesteps | 82095    |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.0154   |
# |    ent_coef        | 0.00522  |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 81994    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -6.71    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2444     |
# |    fps             | 37       |
# |    time_elapsed    | 2181     |
# |    total_timesteps | 82155    |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.01     |
# |    ent_coef        | 0.00512  |
# |    ent_coef_loss   | 0.272    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82054    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -6.6     |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2448     |
# |    fps             | 37       |
# |    time_elapsed    | 2183     |
# |    total_timesteps | 82217    |
# | train/             |          |
# |    actor_loss      | 1.5      |
# |    critic_loss     | 0.0864   |
# |    ent_coef        | 0.00509  |
# |    ent_coef_loss   | -0.773   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82116    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | -6.56    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2452     |
# |    fps             | 37       |
# |    time_elapsed    | 2186     |
# |    total_timesteps | 82312    |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.0151   |
# |    ent_coef        | 0.00513  |
# |    ent_coef_loss   | 0.234    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82211    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | -6.65    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2456     |
# |    fps             | 37       |
# |    time_elapsed    | 2188     |
# |    total_timesteps | 82392    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.00601  |
# |    ent_coef        | 0.00502  |
# |    ent_coef_loss   | 0.603    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82291    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | -6.71    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2460     |
# |    fps             | 37       |
# |    time_elapsed    | 2190     |
# |    total_timesteps | 82471    |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 0.00761  |
# |    ent_coef        | 0.0051   |
# |    ent_coef_loss   | 0.342    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82370    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | -6.66    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2464     |
# |    fps             | 37       |
# |    time_elapsed    | 2192     |
# |    total_timesteps | 82539    |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.00726  |
# |    ent_coef        | 0.00509  |
# |    ent_coef_loss   | 0.576    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82438    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.5     |
# |    ep_rew_mean     | -6.66    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2468     |
# |    fps             | 37       |
# |    time_elapsed    | 2194     |
# |    total_timesteps | 82609    |
# | train/             |          |
# |    actor_loss      | 1.63     |
# |    critic_loss     | 0.0234   |
# |    ent_coef        | 0.00499  |
# |    ent_coef_loss   | -0.0687  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82508    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | -6.65    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2472     |
# |    fps             | 37       |
# |    time_elapsed    | 2196     |
# |    total_timesteps | 82692    |
# | train/             |          |
# |    actor_loss      | 1.5      |
# |    critic_loss     | 0.012    |
# |    ent_coef        | 0.00511  |
# |    ent_coef_loss   | -0.441   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82591    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.6     |
# |    ep_rew_mean     | -6.64    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2476     |
# |    fps             | 37       |
# |    time_elapsed    | 2198     |
# |    total_timesteps | 82766    |
# | train/             |          |
# |    actor_loss      | 1.5      |
# |    critic_loss     | 0.00511  |
# |    ent_coef        | 0.00512  |
# |    ent_coef_loss   | -0.745   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82665    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | -6.72    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2480     |
# |    fps             | 37       |
# |    time_elapsed    | 2201     |
# |    total_timesteps | 82865    |
# | train/             |          |
# |    actor_loss      | 1.63     |
# |    critic_loss     | 0.0296   |
# |    ent_coef        | 0.00519  |
# |    ent_coef_loss   | 0.877    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82764    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | -6.72    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2484     |
# |    fps             | 37       |
# |    time_elapsed    | 2203     |
# |    total_timesteps | 82956    |
# | train/             |          |
# |    actor_loss      | 1.53     |
# |    critic_loss     | 0.005    |
# |    ent_coef        | 0.00501  |
# |    ent_coef_loss   | 0.247    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82855    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | -6.68    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2488     |
# |    fps             | 37       |
# |    time_elapsed    | 2205     |
# |    total_timesteps | 83030    |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.0141   |
# |    ent_coef        | 0.00486  |
# |    ent_coef_loss   | 0.589    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 82929    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | -6.62    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2492     |
# |    fps             | 37       |
# |    time_elapsed    | 2208     |
# |    total_timesteps | 83139    |
# | train/             |          |
# |    actor_loss      | 1.44     |
# |    critic_loss     | 0.0138   |
# |    ent_coef        | 0.00486  |
# |    ent_coef_loss   | -1.17    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83038    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -6.69    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 2496     |
# |    fps             | 37       |
# |    time_elapsed    | 2210     |
# |    total_timesteps | 83228    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.0241   |
# |    ent_coef        | 0.0048   |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83127    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -6.79    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 37       |
# |    time_elapsed    | 2213     |
# |    total_timesteps | 83307    |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.0614   |
# |    ent_coef        | 0.0048   |
# |    ent_coef_loss   | -0.203   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83206    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -6.83    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 2504     |
# |    fps             | 37       |
# |    time_elapsed    | 2215     |
# |    total_timesteps | 83386    |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.00422  |
# |    ent_coef        | 0.00478  |
# |    ent_coef_loss   | 2.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83285    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -6.78    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 2508     |
# |    fps             | 37       |
# |    time_elapsed    | 2216     |
# |    total_timesteps | 83450    |
# | train/             |          |
# |    actor_loss      | 1.63     |
# |    critic_loss     | 0.00651  |
# |    ent_coef        | 0.00505  |
# |    ent_coef_loss   | 1.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83349    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -6.9     |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 2512     |
# |    fps             | 37       |
# |    time_elapsed    | 2219     |
# |    total_timesteps | 83545    |
# | train/             |          |
# |    actor_loss      | 1.56     |
# |    critic_loss     | 0.0097   |
# |    ent_coef        | 0.00504  |
# |    ent_coef_loss   | 1.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83444    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -6.73    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2516     |
# |    fps             | 37       |
# |    time_elapsed    | 2221     |
# |    total_timesteps | 83616    |
# | train/             |          |
# |    actor_loss      | 1.34     |
# |    critic_loss     | 0.0299   |
# |    ent_coef        | 0.00496  |
# |    ent_coef_loss   | -0.158   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83515    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | -6.62    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 2520     |
# |    fps             | 37       |
# |    time_elapsed    | 2223     |
# |    total_timesteps | 83685    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.0187   |
# |    ent_coef        | 0.005    |
# |    ent_coef_loss   | 0.181    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 83584    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -6.79    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 2524     |
# |    fps             | 37       |
# |    time_elapsed    | 2225     |
# |    total_timesteps | 83773    |
# ...
# |    n_updates       | 97766    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -7.19    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3220     |
# |    fps             | 37       |
# |    time_elapsed    | 2608     |
# |    total_timesteps | 97951    |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.00877  |
# |    ent_coef        | 0.00526  |
# |    ent_coef_loss   | -0.0129  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97850    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.13    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3224     |
# |    fps             | 37       |
# |    time_elapsed    | 2610     |
# |    total_timesteps | 98020    |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.034    |
# |    ent_coef        | 0.00539  |
# |    ent_coef_loss   | -0.212   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97919    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.19    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3228     |
# |    fps             | 37       |
# |    time_elapsed    | 2612     |
# |    total_timesteps | 98093    |
# | train/             |          |
# |    actor_loss      | 1.59     |
# |    critic_loss     | 0.00865  |
# |    ent_coef        | 0.0053   |
# |    ent_coef_loss   | 0.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97992    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -7.12    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3232     |
# |    fps             | 37       |
# |    time_elapsed    | 2614     |
# |    total_timesteps | 98157    |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 0.00536  |
# |    ent_coef        | 0.00546  |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98056    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.2     |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3236     |
# |    fps             | 37       |
# |    time_elapsed    | 2616     |
# |    total_timesteps | 98246    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.00684  |
# |    ent_coef        | 0.00535  |
# |    ent_coef_loss   | 0.776    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98145    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -7.26    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3240     |
# |    fps             | 37       |
# |    time_elapsed    | 2618     |
# |    total_timesteps | 98340    |
# | train/             |          |
# |    actor_loss      | 1.72     |
# |    critic_loss     | 0.00689  |
# |    ent_coef        | 0.00524  |
# |    ent_coef_loss   | 1.03     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98239    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -7.2     |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3244     |
# |    fps             | 37       |
# |    time_elapsed    | 2620     |
# |    total_timesteps | 98421    |
# | train/             |          |
# |    actor_loss      | 1.5      |
# |    critic_loss     | 0.00553  |
# |    ent_coef        | 0.00528  |
# |    ent_coef_loss   | 0.387    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98320    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.21    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3248     |
# |    fps             | 37       |
# |    time_elapsed    | 2623     |
# |    total_timesteps | 98497    |
# | train/             |          |
# |    actor_loss      | 1.84     |
# |    critic_loss     | 0.00494  |
# |    ent_coef        | 0.00522  |
# |    ent_coef_loss   | 0.66     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98396    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.08    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3252     |
# |    fps             | 37       |
# |    time_elapsed    | 2625     |
# |    total_timesteps | 98565    |
# | train/             |          |
# |    actor_loss      | 1.52     |
# |    critic_loss     | 0.00598  |
# |    ent_coef        | 0.00527  |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98464    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.17    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3256     |
# |    fps             | 37       |
# |    time_elapsed    | 2627     |
# |    total_timesteps | 98645    |
# | train/             |          |
# |    actor_loss      | 1.7      |
# |    critic_loss     | 0.00834  |
# |    ent_coef        | 0.00523  |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98544    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -7.21    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3260     |
# |    fps             | 37       |
# |    time_elapsed    | 2629     |
# |    total_timesteps | 98737    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.013    |
# |    ent_coef        | 0.00538  |
# |    ent_coef_loss   | 0.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98636    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.14    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3264     |
# |    fps             | 37       |
# |    time_elapsed    | 2631     |
# |    total_timesteps | 98802    |
# | train/             |          |
# |    actor_loss      | 1.58     |
# |    critic_loss     | 0.0267   |
# |    ent_coef        | 0.00548  |
# |    ent_coef_loss   | 0.322    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98701    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | -7.11    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3268     |
# |    fps             | 37       |
# |    time_elapsed    | 2633     |
# |    total_timesteps | 98873    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.0332   |
# |    ent_coef        | 0.00545  |
# |    ent_coef_loss   | 0.581    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98772    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | -7.06    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3272     |
# |    fps             | 37       |
# |    time_elapsed    | 2636     |
# |    total_timesteps | 98961    |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.00915  |
# |    ent_coef        | 0.00539  |
# |    ent_coef_loss   | -0.00428 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98860    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -7.02    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3276     |
# |    fps             | 37       |
# |    time_elapsed    | 2638     |
# |    total_timesteps | 99056    |
# | train/             |          |
# |    actor_loss      | 1.55     |
# |    critic_loss     | 0.024    |
# |    ent_coef        | 0.00536  |
# |    ent_coef_loss   | 0.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 98955    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20       |
# |    ep_rew_mean     | -7.07    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3280     |
# |    fps             | 37       |
# |    time_elapsed    | 2640     |
# |    total_timesteps | 99129    |
# | train/             |          |
# |    actor_loss      | 1.54     |
# |    critic_loss     | 0.00657  |
# |    ent_coef        | 0.00526  |
# |    ent_coef_loss   | 0.721    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99028    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -7.14    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3284     |
# |    fps             | 37       |
# |    time_elapsed    | 2642     |
# |    total_timesteps | 99209    |
# | train/             |          |
# |    actor_loss      | 1.75     |
# |    critic_loss     | 0.00647  |
# |    ent_coef        | 0.00529  |
# |    ent_coef_loss   | 0.893    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99108    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | -7.22    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3288     |
# |    fps             | 37       |
# |    time_elapsed    | 2645     |
# |    total_timesteps | 99307    |
# | train/             |          |
# |    actor_loss      | 1.45     |
# |    critic_loss     | 0.00925  |
# |    ent_coef        | 0.0054   |
# |    ent_coef_loss   | -0.463   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99206    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.5     |
# |    ep_rew_mean     | -7.2     |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3292     |
# |    fps             | 37       |
# |    time_elapsed    | 2647     |
# |    total_timesteps | 99397    |
# | train/             |          |
# |    actor_loss      | 1.62     |
# |    critic_loss     | 0.00572  |
# |    ent_coef        | 0.00553  |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99296    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.15    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3296     |
# |    fps             | 37       |
# |    time_elapsed    | 2649     |
# |    total_timesteps | 99467    |
# | train/             |          |
# |    actor_loss      | 1.65     |
# |    critic_loss     | 0.0395   |
# |    ent_coef        | 0.00549  |
# |    ent_coef_loss   | -1.33    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99366    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.13    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 37       |
# |    time_elapsed    | 2651     |
# |    total_timesteps | 99540    |
# | train/             |          |
# |    actor_loss      | 1.6      |
# |    critic_loss     | 0.00965  |
# |    ent_coef        | 0.00548  |
# |    ent_coef_loss   | 0.475    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99439    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.1     |
# |    ep_rew_mean     | -7.12    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3304     |
# |    fps             | 37       |
# |    time_elapsed    | 2653     |
# |    total_timesteps | 99604    |
# | train/             |          |
# |    actor_loss      | 1.72     |
# |    critic_loss     | 0.0291   |
# |    ent_coef        | 0.00564  |
# |    ent_coef_loss   | 0.139    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99503    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.8     |
# |    ep_rew_mean     | -6.99    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 3308     |
# |    fps             | 37       |
# |    time_elapsed    | 2655     |
# |    total_timesteps | 99685    |
# | train/             |          |
# |    actor_loss      | 1.81     |
# |    critic_loss     | 0.00595  |
# |    ent_coef        | 0.0056   |
# |    ent_coef_loss   | 0.368    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99584    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.9     |
# |    ep_rew_mean     | -7       |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3312     |
# |    fps             | 37       |
# |    time_elapsed    | 2657     |
# |    total_timesteps | 99777    |
# | train/             |          |
# |    actor_loss      | 1.66     |
# |    critic_loss     | 0.00947  |
# |    ent_coef        | 0.00564  |
# |    ent_coef_loss   | -0.516   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99676    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.7     |
# |    ep_rew_mean     | -6.84    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3316     |
# |    fps             | 37       |
# |    time_elapsed    | 2659     |
# |    total_timesteps | 99841    |
# | train/             |          |
# |    actor_loss      | 1.57     |
# |    critic_loss     | 0.009    |
# |    ent_coef        | 0.00563  |
# |    ent_coef_loss   | -0.617   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99740    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 19.8     |
# |    ep_rew_mean     | -6.85    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3320     |
# |    fps             | 37       |
# |    time_elapsed    | 2662     |
# |    total_timesteps | 99929    |
# | train/             |          |
# |    actor_loss      | 1.46     |
# |    critic_loss     | 0.0567   |
# |    ent_coef        | 0.00568  |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 99828    |
# ---------------------------------

# %%
# Load saved model
model = SAC.load('her_sac_highway', env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# #### Evaluate the agent

# %%
# we use the gym >v.26 API here. Note that you could also wrap the env in a DummyVecEnv
# which allows you to use a simplified API
obs, _ = env.reset()

# Evaluate the agent
episode_reward = 0
for _ in range(1000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = truncated or terminated
    episode_reward += reward
    if done or info.get("is_success", False):
        print("Reward:", episode_reward, "Success?", info.get("is_success", False))
        episode_reward = 0.0
        obs, _ = env.reset()
# Out:
# Reward: -12.985952643578237 Success? False
# Reward: -2.4818934176069205 Success? True
# Reward: -6.200242145528466 Success? True
# Reward: -6.804976008673456 Success? True
# Reward: -2.4973094134231113 Success? True
# Reward: -7.2051187561172165 Success? True
# Reward: -8.514093503910791 Success? True
# Reward: -5.985852771201228 Success? True
# Reward: -4.641636335505931 Success? True
# Reward: -3.435680310102163 Success? True
# Reward: -4.113605305653299 Success? True
# Reward: -11.414662685014392 Success? True
# Reward: -5.474037742222492 Success? True
# Reward: -4.441864032818608 Success? True
# Reward: -5.915973986098036 Success? True
# Reward: -14.548069039852653 Success? False
# Reward: -2.5207500819519884 Success? True
# Reward: -8.210777452752591 Success? True
# Reward: -13.780042800807317 Success? False
# Reward: -4.824219766937436 Success? True
# Reward: -7.012449805631088 Success? True
# Reward: -12.830665892762651 Success? False
# Reward: -7.806276284088399 Success? True
# Reward: -8.93582105393842 Success? True
# Reward: -6.778253343931874 Success? True
# Reward: -6.421909690078724 Success? True
# Reward: -5.834506628223027 Success? True
# Reward: -7.689711702518855 Success? True
# Reward: -5.674216301173213 Success? True
# Reward: -2.4883470785606043 Success? True
# Reward: -7.685402312117411 Success? True
# Reward: -5.793583911763525 Success? True
# Reward: -6.045383233264167 Success? True
# Reward: -5.265599233766351 Success? True
# Reward: -6.672192238972843 Success? True
# Reward: -5.299861298988482 Success? True
# Reward: -2.527689833385542 Success? True
# Reward: -8.226126508048539 Success? True
# Reward: -9.534195514047989 Success? True
# Reward: -3.475584569539661 Success? True
# Reward: -10.475720626245405 Success? True
# Reward: -2.637910168719176 Success? True
# Reward: -6.916170857582949 Success? True
# Reward: -6.476302235083262 Success? True
# Reward: -6.460717791836687 Success? True
# Reward: -3.3177162628591406 Success? True
# Reward: -3.2112387914927267 Success? True
# Reward: -7.8135525766073535 Success? True
# Reward: -5.383757019980928 Success? True
# Reward: -6.329725549623401 Success? True
# Reward: -7.7954481095676895 Success? True

# %% [markdown]
# ### Train DDPG agent

# %%
# Create the action noise object that will be used for exploration
n_actions = env.action_space.shape[0]
noise_std = 0.2
action_noise = NormalActionNoise(
    mean=np.zeros(n_actions), sigma=noise_std * np.ones(n_actions)
)

model = DDPG(
    "MultiInputPolicy",
    env,
    replay_buffer_class=HerReplayBuffer,
    replay_buffer_kwargs=dict(
        n_sampled_goal=4,
        goal_selection_strategy="future",
    ),
    verbose=1,
    buffer_size=int(1e6),
    learning_rate=1e-3,
    action_noise=action_noise,
    gamma=0.95,
    batch_size=256,
    policy_kwargs=dict(net_arch=[256, 256, 256]),
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# Train for 2e5 steps
model.learn(int(2e5))
# Save the trained agent
model.save('her_ddpg_highway')
# Out:
# Streaming output truncated to the last 5000 lines.
# |    time_elapsed    | 3715     |
# |    total_timesteps | 172274   |
# | train/             |          |
# |    actor_loss      | 0.827    |
# |    critic_loss     | 0.00734  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172164   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.3     |
# |    ep_rew_mean     | -8.13    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3164     |
# |    fps             | 46       |
# |    time_elapsed    | 3717     |
# |    total_timesteps | 172369   |
# | train/             |          |
# |    actor_loss      | 0.853    |
# |    critic_loss     | 0.011    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172262   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.4     |
# |    ep_rew_mean     | -8.17    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3168     |
# |    fps             | 46       |
# |    time_elapsed    | 3719     |
# |    total_timesteps | 172456   |
# | train/             |          |
# |    actor_loss      | 0.844    |
# |    critic_loss     | 0.00659  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172347   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | -8.13    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3172     |
# |    fps             | 46       |
# |    time_elapsed    | 3720     |
# |    total_timesteps | 172538   |
# | train/             |          |
# |    actor_loss      | 0.857    |
# |    critic_loss     | 0.00756  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27.1     |
# |    ep_rew_mean     | -8.13    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3176     |
# |    fps             | 46       |
# |    time_elapsed    | 3723     |
# |    total_timesteps | 172626   |
# | train/             |          |
# |    actor_loss      | 0.821    |
# |    critic_loss     | 0.00746  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172522   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 27       |
# |    ep_rew_mean     | -8.04    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3180     |
# |    fps             | 46       |
# |    time_elapsed    | 3725     |
# |    total_timesteps | 172704   |
# | train/             |          |
# |    actor_loss      | 0.811    |
# |    critic_loss     | 0.0117   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172597   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.7     |
# |    ep_rew_mean     | -8.06    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3184     |
# |    fps             | 46       |
# |    time_elapsed    | 3726     |
# |    total_timesteps | 172785   |
# | train/             |          |
# |    actor_loss      | 0.874    |
# |    critic_loss     | 0.00977  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172681   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26       |
# |    ep_rew_mean     | -7.8     |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3188     |
# |    fps             | 46       |
# |    time_elapsed    | 3728     |
# |    total_timesteps | 172847   |
# | train/             |          |
# |    actor_loss      | 0.863    |
# |    critic_loss     | 0.0116   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172739   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.6     |
# |    ep_rew_mean     | -7.73    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3192     |
# |    fps             | 46       |
# |    time_elapsed    | 3729     |
# |    total_timesteps | 172922   |
# | train/             |          |
# |    actor_loss      | 0.834    |
# |    critic_loss     | 0.00572  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172809   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.6     |
# |    ep_rew_mean     | -7.78    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3196     |
# |    fps             | 46       |
# |    time_elapsed    | 3731     |
# |    total_timesteps | 173002   |
# | train/             |          |
# |    actor_loss      | 0.86     |
# |    critic_loss     | 0.00663  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172892   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.5     |
# |    ep_rew_mean     | -7.75    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3200     |
# |    fps             | 46       |
# |    time_elapsed    | 3733     |
# |    total_timesteps | 173080   |
# | train/             |          |
# |    actor_loss      | 0.841    |
# |    critic_loss     | 0.00971  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 172974   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -7.68    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3204     |
# |    fps             | 46       |
# |    time_elapsed    | 3735     |
# |    total_timesteps | 173170   |
# | train/             |          |
# |    actor_loss      | 0.883    |
# |    critic_loss     | 0.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173061   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -7.63    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3208     |
# |    fps             | 46       |
# |    time_elapsed    | 3737     |
# |    total_timesteps | 173251   |
# | train/             |          |
# |    actor_loss      | 0.833    |
# |    critic_loss     | 0.00762  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173148   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.7     |
# |    ep_rew_mean     | -7.62    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3212     |
# |    fps             | 46       |
# |    time_elapsed    | 3739     |
# |    total_timesteps | 173330   |
# | train/             |          |
# |    actor_loss      | 0.836    |
# |    critic_loss     | 0.00658  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173223   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.4     |
# |    ep_rew_mean     | -7.57    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3216     |
# |    fps             | 46       |
# |    time_elapsed    | 3740     |
# |    total_timesteps | 173407   |
# | train/             |          |
# |    actor_loss      | 0.859    |
# |    critic_loss     | 0.00851  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173297   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.6     |
# |    ep_rew_mean     | -7.54    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3220     |
# |    fps             | 46       |
# |    time_elapsed    | 3743     |
# |    total_timesteps | 173511   |
# | train/             |          |
# |    actor_loss      | 0.831    |
# |    critic_loss     | 0.00948  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.1     |
# |    ep_rew_mean     | -7.8     |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3224     |
# |    fps             | 46       |
# |    time_elapsed    | 3745     |
# |    total_timesteps | 173628   |
# | train/             |          |
# |    actor_loss      | 0.834    |
# |    critic_loss     | 0.00921  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173511   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -7.28    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3228     |
# |    fps             | 46       |
# |    time_elapsed    | 3748     |
# |    total_timesteps | 173744   |
# | train/             |          |
# |    actor_loss      | 0.845    |
# |    critic_loss     | 0.00755  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173641   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | -7.18    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3232     |
# |    fps             | 46       |
# |    time_elapsed    | 3750     |
# |    total_timesteps | 173805   |
# | train/             |          |
# |    actor_loss      | 0.833    |
# |    critic_loss     | 0.00859  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173702   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -7.28    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3236     |
# |    fps             | 46       |
# |    time_elapsed    | 3751     |
# |    total_timesteps | 173881   |
# | train/             |          |
# |    actor_loss      | 0.845    |
# |    critic_loss     | 0.00587  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173780   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3240     |
# |    fps             | 46       |
# |    time_elapsed    | 3753     |
# |    total_timesteps | 173968   |
# | train/             |          |
# |    actor_loss      | 0.857    |
# |    critic_loss     | 0.00624  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173853   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | -7.13    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3244     |
# |    fps             | 46       |
# |    time_elapsed    | 3755     |
# |    total_timesteps | 174039   |
# | train/             |          |
# |    actor_loss      | 0.844    |
# |    critic_loss     | 0.00623  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 173932   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3248     |
# |    fps             | 46       |
# |    time_elapsed    | 3757     |
# |    total_timesteps | 174163   |
# | train/             |          |
# |    actor_loss      | 0.806    |
# |    critic_loss     | 0.00559  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174052   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.3     |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 3252     |
# |    fps             | 46       |
# |    time_elapsed    | 3760     |
# |    total_timesteps | 174266   |
# | train/             |          |
# |    actor_loss      | 0.819    |
# |    critic_loss     | 0.0065   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174154   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.35    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 3256     |
# |    fps             | 46       |
# |    time_elapsed    | 3763     |
# |    total_timesteps | 174365   |
# | train/             |          |
# |    actor_loss      | 0.82     |
# |    critic_loss     | 0.00868  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174255   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.39    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 3260     |
# |    fps             | 46       |
# |    time_elapsed    | 3764     |
# |    total_timesteps | 174439   |
# | train/             |          |
# |    actor_loss      | 0.815    |
# |    critic_loss     | 0.011    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174329   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.32    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 3264     |
# |    fps             | 46       |
# |    time_elapsed    | 3766     |
# |    total_timesteps | 174527   |
# | train/             |          |
# |    actor_loss      | 0.808    |
# |    critic_loss     | 0.0103   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174423   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.38    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3268     |
# |    fps             | 46       |
# |    time_elapsed    | 3768     |
# |    total_timesteps | 174615   |
# | train/             |          |
# |    actor_loss      | 0.803    |
# |    critic_loss     | 0.00734  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174507   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.36    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 3272     |
# |    fps             | 46       |
# |    time_elapsed    | 3769     |
# |    total_timesteps | 174690   |
# | train/             |          |
# |    actor_loss      | 0.841    |
# |    critic_loss     | 0.0111   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174586   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.34    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 3276     |
# |    fps             | 46       |
# |    time_elapsed    | 3771     |
# |    total_timesteps | 174764   |
# | train/             |          |
# |    actor_loss      | 0.821    |
# |    critic_loss     | 0.0074   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174655   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.42    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3280     |
# |    fps             | 46       |
# |    time_elapsed    | 3774     |
# |    total_timesteps | 174848   |
# | train/             |          |
# |    actor_loss      | 0.784    |
# |    critic_loss     | 0.00649  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174746   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.39    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 3284     |
# |    fps             | 46       |
# |    time_elapsed    | 3775     |
# |    total_timesteps | 174934   |
# | train/             |          |
# |    actor_loss      | 0.83     |
# |    critic_loss     | 0.00707  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174831   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | -7.54    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 3288     |
# |    fps             | 46       |
# |    time_elapsed    | 3777     |
# |    total_timesteps | 175022   |
# | train/             |          |
# |    actor_loss      | 0.821    |
# |    critic_loss     | 0.011    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174914   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | -7.6     |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3292     |
# |    fps             | 46       |
# |    time_elapsed    | 3779     |
# |    total_timesteps | 175095   |
# | train/             |          |
# |    actor_loss      | 0.839    |
# |    critic_loss     | 0.00796  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 174988   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.56    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3296     |
# |    fps             | 46       |
# |    time_elapsed    | 3780     |
# |    total_timesteps | 175165   |
# | train/             |          |
# |    actor_loss      | 0.817    |
# |    critic_loss     | 0.0121   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175064   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | -7.54    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 46       |
# |    time_elapsed    | 3782     |
# |    total_timesteps | 175247   |
# | train/             |          |
# |    actor_loss      | 0.798    |
# |    critic_loss     | 0.00865  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175139   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -7.57    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3304     |
# |    fps             | 46       |
# |    time_elapsed    | 3785     |
# |    total_timesteps | 175355   |
# | train/             |          |
# |    actor_loss      | 0.827    |
# |    critic_loss     | 0.00908  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175232   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | -7.65    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3308     |
# |    fps             | 46       |
# |    time_elapsed    | 3787     |
# |    total_timesteps | 175433   |
# | train/             |          |
# |    actor_loss      | 0.808    |
# |    critic_loss     | 0.0075   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175327   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | -7.74    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3312     |
# |    fps             | 46       |
# |    time_elapsed    | 3789     |
# |    total_timesteps | 175543   |
# | train/             |          |
# |    actor_loss      | 0.79     |
# |    critic_loss     | 0.0087   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175420   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.5     |
# |    ep_rew_mean     | -7.96    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3316     |
# |    fps             | 46       |
# |    time_elapsed    | 3792     |
# |    total_timesteps | 175661   |
# | train/             |          |
# |    actor_loss      | 0.825    |
# |    critic_loss     | 0.00775  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175548   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | -8.06    |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3320     |
# |    fps             | 46       |
# |    time_elapsed    | 3793     |
# |    total_timesteps | 175747   |
# | train/             |          |
# |    actor_loss      | 0.828    |
# |    critic_loss     | 0.0165   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175638   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | -7.78    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 3324     |
# |    fps             | 46       |
# |    time_elapsed    | 3795     |
# |    total_timesteps | 175827   |
# | train/             |          |
# |    actor_loss      | 0.789    |
# |    critic_loss     | 0.0128   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175715   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.76    |
# |    success_rate    | 0.87     |
# | time/              |          |
# |    episodes        | 3328     |
# |    fps             | 46       |
# |    time_elapsed    | 3798     |
# |    total_timesteps | 175906   |
# | train/             |          |
# |    actor_loss      | 0.82     |
# |    critic_loss     | 0.00838  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175793   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -7.94    |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 3332     |
# |    fps             | 46       |
# |    time_elapsed    | 3800     |
# |    total_timesteps | 175994   |
# | train/             |          |
# |    actor_loss      | 0.797    |
# |    critic_loss     | 0.00635  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175889   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -7.97    |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 3336     |
# |    fps             | 46       |
# |    time_elapsed    | 3801     |
# |    total_timesteps | 176074   |
# | train/             |          |
# |    actor_loss      | 0.801    |
# |    critic_loss     | 0.00761  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 175962   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -8.02    |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 3340     |
# |    fps             | 46       |
# |    time_elapsed    | 3803     |
# |    total_timesteps | 176163   |
# | train/             |          |
# |    actor_loss      | 0.831    |
# |    critic_loss     | 0.00779  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176051   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | -8.26    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 3344     |
# |    fps             | 46       |
# |    time_elapsed    | 3806     |
# |    total_timesteps | 176279   |
# | train/             |          |
# |    actor_loss      | 0.825    |
# |    critic_loss     | 0.0104   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176167   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | -8.16    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 3348     |
# |    fps             | 46       |
# |    time_elapsed    | 3807     |
# |    total_timesteps | 176367   |
# | train/             |          |
# |    actor_loss      | 0.78     |
# |    critic_loss     | 0.00757  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176255   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -8.09    |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 3352     |
# |    fps             | 46       |
# |    time_elapsed    | 3810     |
# |    total_timesteps | 176458   |
# | train/             |          |
# |    actor_loss      | 0.808    |
# |    critic_loss     | 0.00711  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176337   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -8.09    |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 3356     |
# |    fps             | 46       |
# |    time_elapsed    | 3812     |
# |    total_timesteps | 176552   |
# | train/             |          |
# |    actor_loss      | 0.801    |
# |    critic_loss     | 0.00657  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | -8.18    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 3360     |
# |    fps             | 46       |
# |    time_elapsed    | 3814     |
# |    total_timesteps | 176636   |
# | train/             |          |
# |    actor_loss      | 0.776    |
# |    critic_loss     | 0.00849  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176533   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -8.27    |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 3364     |
# |    fps             | 46       |
# |    time_elapsed    | 3816     |
# |    total_timesteps | 176719   |
# | train/             |          |
# |    actor_loss      | 0.777    |
# |    critic_loss     | 0.00997  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176612   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -8.17    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 3368     |
# |    fps             | 46       |
# |    time_elapsed    | 3817     |
# |    total_timesteps | 176808   |
# | train/             |          |
# |    actor_loss      | 0.771    |
# |    critic_loss     | 0.0156   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176684   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | -8.3     |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 3372     |
# |    fps             | 46       |
# |    time_elapsed    | 3820     |
# |    total_timesteps | 176917   |
# | train/             |          |
# |    actor_loss      | 0.784    |
# |    critic_loss     | 0.00772  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176800   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | -8.34    |
# |    success_rate    | 0.83     |
# | time/              |          |
# |    episodes        | 3376     |
# |    fps             | 46       |
# |    time_elapsed    | 3823     |
# |    total_timesteps | 177009   |
# | train/             |          |
# |    actor_loss      | 0.776    |
# |    critic_loss     | 0.00991  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176894   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | -8.28    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 3380     |
# |    fps             | 46       |
# |    time_elapsed    | 3824     |
# |    total_timesteps | 177089   |
# | train/             |          |
# |    actor_loss      | 0.78     |
# |    critic_loss     | 0.00796  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 176982   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.3     |
# |    ep_rew_mean     | -8.23    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 3384     |
# |    fps             | 46       |
# |    time_elapsed    | 3826     |
# |    total_timesteps | 177165   |
# | train/             |          |
# |    actor_loss      | 0.777    |
# |    critic_loss     | 0.00831  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177062   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | -8.23    |
# |    success_rate    | 0.84     |
# | time/              |          |
# |    episodes        | 3388     |
# |    fps             | 46       |
# |    time_elapsed    | 3828     |
# |    total_timesteps | 177265   |
# | train/             |          |
# |    actor_loss      | 0.796    |
# |    critic_loss     | 0.00564  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177143   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.6     |
# |    ep_rew_mean     | -8.26    |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 3392     |
# |    fps             | 46       |
# |    time_elapsed    | 3830     |
# |    total_timesteps | 177359   |
# | train/             |          |
# |    actor_loss      | 0.757    |
# |    critic_loss     | 0.0201   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177246   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.8     |
# |    ep_rew_mean     | -8.27    |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 3396     |
# |    fps             | 46       |
# |    time_elapsed    | 3832     |
# |    total_timesteps | 177446   |
# | train/             |          |
# |    actor_loss      | 0.795    |
# |    critic_loss     | 0.0058   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177338   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.1     |
# |    ep_rew_mean     | -8.39    |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 3400     |
# |    fps             | 46       |
# |    time_elapsed    | 3835     |
# |    total_timesteps | 177552   |
# | train/             |          |
# |    actor_loss      | 0.775    |
# |    critic_loss     | 0.00785  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177431   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.8     |
# |    ep_rew_mean     | -8.3     |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 3404     |
# |    fps             | 46       |
# |    time_elapsed    | 3837     |
# |    total_timesteps | 177636   |
# | train/             |          |
# |    actor_loss      | 0.799    |
# |    critic_loss     | 0.0056   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177532   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.7     |
# |    ep_rew_mean     | -8.22    |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 3408     |
# |    fps             | 46       |
# |    time_elapsed    | 3838     |
# |    total_timesteps | 177706   |
# | train/             |          |
# |    actor_loss      | 0.805    |
# |    critic_loss     | 0.0157   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177604   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.4     |
# |    ep_rew_mean     | -8.14    |
# |    success_rate    | 0.85     |
# | time/              |          |
# |    episodes        | 3412     |
# |    fps             | 46       |
# |    time_elapsed    | 3840     |
# |    total_timesteps | 177781   |
# | train/             |          |
# |    actor_loss      | 0.8      |
# |    critic_loss     | 0.0136   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177681   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | -7.93    |
# |    success_rate    | 0.86     |
# | time/              |          |
# |    episodes        | 3416     |
# |    fps             | 46       |
# |    time_elapsed    | 3842     |
# |    total_timesteps | 177885   |
# | train/             |          |
# |    actor_loss      | 0.78     |
# |    critic_loss     | 0.00937  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177765   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | -7.78    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 3420     |
# |    fps             | 46       |
# |    time_elapsed    | 3844     |
# |    total_timesteps | 177960   |
# | train/             |          |
# |    actor_loss      | 0.751    |
# |    critic_loss     | 0.00662  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177857   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.1     |
# |    ep_rew_mean     | -7.79    |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 3424     |
# |    fps             | 46       |
# |    time_elapsed    | 3845     |
# |    total_timesteps | 178037   |
# | train/             |          |
# |    actor_loss      | 0.768    |
# |    critic_loss     | 0.0139   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 177929   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | -7.82    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 3428     |
# |    fps             | 46       |
# |    time_elapsed    | 3848     |
# |    total_timesteps | 178127   |
# | train/             |          |
# |    actor_loss      | 0.771    |
# |    critic_loss     | 0.00762  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178003   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | -7.78    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 3432     |
# |    fps             | 46       |
# |    time_elapsed    | 3850     |
# |    total_timesteps | 178211   |
# | train/             |          |
# |    actor_loss      | 0.796    |
# |    critic_loss     | 0.0155   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178103   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | -7.74    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 3436     |
# |    fps             | 46       |
# |    time_elapsed    | 3852     |
# |    total_timesteps | 178299   |
# | train/             |          |
# |    actor_loss      | 0.828    |
# |    critic_loss     | 0.00637  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178195   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22.2     |
# |    ep_rew_mean     | -7.63    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3440     |
# |    fps             | 46       |
# |    time_elapsed    | 3854     |
# |    total_timesteps | 178386   |
# | train/             |          |
# |    actor_loss      | 0.797    |
# |    critic_loss     | 0.00599  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178273   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 22       |
# |    ep_rew_mean     | -7.56    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3444     |
# |    fps             | 46       |
# |    time_elapsed    | 3856     |
# |    total_timesteps | 178480   |
# | train/             |          |
# |    actor_loss      | 0.794    |
# |    critic_loss     | 0.009    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178375   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.9     |
# |    ep_rew_mean     | -7.53    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3448     |
# |    fps             | 46       |
# |    time_elapsed    | 3857     |
# |    total_timesteps | 178552   |
# | train/             |          |
# |    actor_loss      | 0.798    |
# |    critic_loss     | 0.0102   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178444   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.8     |
# |    ep_rew_mean     | -7.55    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3452     |
# |    fps             | 46       |
# |    time_elapsed    | 3860     |
# |    total_timesteps | 178639   |
# | train/             |          |
# |    actor_loss      | 0.8      |
# |    critic_loss     | 0.00813  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178533   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.39    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3456     |
# |    fps             | 46       |
# |    time_elapsed    | 3861     |
# |    total_timesteps | 178710   |
# | train/             |          |
# |    actor_loss      | 0.787    |
# |    critic_loss     | 0.00737  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178605   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | -7.37    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3460     |
# |    fps             | 46       |
# |    time_elapsed    | 3863     |
# |    total_timesteps | 178808   |
# | train/             |          |
# |    actor_loss      | 0.84     |
# |    critic_loss     | 0.011    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178683   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.3     |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 3464     |
# |    fps             | 46       |
# |    time_elapsed    | 3865     |
# |    total_timesteps | 178879   |
# | train/             |          |
# |    actor_loss      | 0.818    |
# |    critic_loss     | 0.00657  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178774   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | -7.38    |
# |    success_rate    | 0.95     |
# | time/              |          |
# |    episodes        | 3468     |
# |    fps             | 46       |
# |    time_elapsed    | 3867     |
# |    total_timesteps | 178977   |
# | train/             |          |
# |    actor_loss      | 0.784    |
# |    critic_loss     | 0.0105   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178868   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.29    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 3472     |
# |    fps             | 46       |
# |    time_elapsed    | 3869     |
# |    total_timesteps | 179077   |
# | train/             |          |
# |    actor_loss      | 0.818    |
# |    critic_loss     | 0.0111   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 178972   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.28    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 3476     |
# |    fps             | 46       |
# |    time_elapsed    | 3871     |
# |    total_timesteps | 179158   |
# | train/             |          |
# |    actor_loss      | 0.82     |
# |    critic_loss     | 0.0112   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179054   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.2     |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 3480     |
# |    fps             | 46       |
# |    time_elapsed    | 3873     |
# |    total_timesteps | 179230   |
# | train/             |          |
# |    actor_loss      | 0.791    |
# |    critic_loss     | 0.0102   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179129   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.96     |
# | time/              |          |
# |    episodes        | 3484     |
# |    fps             | 46       |
# |    time_elapsed    | 3875     |
# |    total_timesteps | 179326   |
# | train/             |          |
# |    actor_loss      | 0.843    |
# |    critic_loss     | 0.00955  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179216   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.37    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3488     |
# |    fps             | 46       |
# |    time_elapsed    | 3877     |
# |    total_timesteps | 179418   |
# | train/             |          |
# |    actor_loss      | 0.842    |
# |    critic_loss     | 0.00662  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179304   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | -7.37    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3492     |
# |    fps             | 46       |
# |    time_elapsed    | 3879     |
# |    total_timesteps | 179526   |
# | train/             |          |
# |    actor_loss      | 0.832    |
# |    critic_loss     | 0.00747  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179419   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.34    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3496     |
# |    fps             | 46       |
# |    time_elapsed    | 3881     |
# |    total_timesteps | 179603   |
# | train/             |          |
# |    actor_loss      | 0.822    |
# |    critic_loss     | 0.00916  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179501   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.24    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3500     |
# |    fps             | 46       |
# |    time_elapsed    | 3883     |
# |    total_timesteps | 179702   |
# | train/             |          |
# |    actor_loss      | 0.839    |
# |    critic_loss     | 0.00947  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179592   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.24    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3504     |
# |    fps             | 46       |
# |    time_elapsed    | 3886     |
# |    total_timesteps | 179787   |
# | train/             |          |
# |    actor_loss      | 0.88     |
# |    critic_loss     | 0.0126   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179674   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.29    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 3508     |
# |    fps             | 46       |
# |    time_elapsed    | 3887     |
# |    total_timesteps | 179859   |
# | train/             |          |
# |    actor_loss      | 0.865    |
# |    critic_loss     | 0.00763  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 179752   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.18    |
# |    success_rate    | 0.94     |
# | time/              |          |
# |    episodes        | 3512     |
# |    fps             | 46       |
# |    time_elapsed    | 3889     |
# |    total_timesteps | 179926   |
# ...
# | train/             |          |
# |    actor_loss      | 0.649    |
# |    critic_loss     | 0.0122   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197478   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.6     |
# |    ep_rew_mean     | -7.76    |
# |    success_rate    | 0.88     |
# | time/              |          |
# |    episodes        | 4296     |
# |    fps             | 46       |
# |    time_elapsed    | 4286     |
# |    total_timesteps | 197642   |
# | train/             |          |
# |    actor_loss      | 0.641    |
# |    critic_loss     | 0.00923  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197535   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.5     |
# |    ep_rew_mean     | -7.6     |
# |    success_rate    | 0.89     |
# | time/              |          |
# |    episodes        | 4300     |
# |    fps             | 46       |
# |    time_elapsed    | 4288     |
# |    total_timesteps | 197735   |
# | train/             |          |
# |    actor_loss      | 0.628    |
# |    critic_loss     | 0.0121   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197633   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.48    |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 4304     |
# |    fps             | 46       |
# |    time_elapsed    | 4289     |
# |    total_timesteps | 197811   |
# | train/             |          |
# |    actor_loss      | 0.683    |
# |    critic_loss     | 0.0172   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197704   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.34    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 4308     |
# |    fps             | 46       |
# |    time_elapsed    | 4291     |
# |    total_timesteps | 197897   |
# | train/             |          |
# |    actor_loss      | 0.6      |
# |    critic_loss     | 0.0129   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197791   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.3     |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 4312     |
# |    fps             | 46       |
# |    time_elapsed    | 4293     |
# |    total_timesteps | 197975   |
# | train/             |          |
# |    actor_loss      | 0.632    |
# |    critic_loss     | 0.0145   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197875   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.24    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4316     |
# |    fps             | 46       |
# |    time_elapsed    | 4294     |
# |    total_timesteps | 198051   |
# | train/             |          |
# |    actor_loss      | 0.639    |
# |    critic_loss     | 0.0145   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 197941   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.3     |
# |    ep_rew_mean     | -7.31    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4320     |
# |    fps             | 46       |
# |    time_elapsed    | 4296     |
# |    total_timesteps | 198131   |
# | train/             |          |
# |    actor_loss      | 0.662    |
# |    critic_loss     | 0.00965  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198021   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.32    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4324     |
# |    fps             | 46       |
# |    time_elapsed    | 4299     |
# |    total_timesteps | 198222   |
# | train/             |          |
# |    actor_loss      | 0.648    |
# |    critic_loss     | 0.0111   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198107   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.33    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4328     |
# |    fps             | 46       |
# |    time_elapsed    | 4300     |
# |    total_timesteps | 198292   |
# | train/             |          |
# |    actor_loss      | 0.638    |
# |    critic_loss     | 0.0141   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198187   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.41    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4332     |
# |    fps             | 46       |
# |    time_elapsed    | 4302     |
# |    total_timesteps | 198382   |
# | train/             |          |
# |    actor_loss      | 0.659    |
# |    critic_loss     | 0.0156   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198275   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.4     |
# |    ep_rew_mean     | -7.46    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4336     |
# |    fps             | 46       |
# |    time_elapsed    | 4304     |
# |    total_timesteps | 198459   |
# | train/             |          |
# |    actor_loss      | 0.607    |
# |    critic_loss     | 0.0107   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198352   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | -7.39    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 4340     |
# |    fps             | 46       |
# |    time_elapsed    | 4305     |
# |    total_timesteps | 198525   |
# | train/             |          |
# |    actor_loss      | 0.682    |
# |    critic_loss     | 0.0113   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198414   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.2     |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4344     |
# |    fps             | 46       |
# |    time_elapsed    | 4307     |
# |    total_timesteps | 198598   |
# | train/             |          |
# |    actor_loss      | 0.625    |
# |    critic_loss     | 0.0138   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198494   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -7.14    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4348     |
# |    fps             | 46       |
# |    time_elapsed    | 4308     |
# |    total_timesteps | 198679   |
# | train/             |          |
# |    actor_loss      | 0.643    |
# |    critic_loss     | 0.011    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198574   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | -7.07    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4352     |
# |    fps             | 46       |
# |    time_elapsed    | 4311     |
# |    total_timesteps | 198763   |
# | train/             |          |
# |    actor_loss      | 0.604    |
# |    critic_loss     | 0.00969  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198654   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.9     |
# |    ep_rew_mean     | -7.27    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4356     |
# |    fps             | 46       |
# |    time_elapsed    | 4313     |
# |    total_timesteps | 198876   |
# | train/             |          |
# |    actor_loss      | 0.678    |
# |    critic_loss     | 0.0124   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198759   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.8     |
# |    ep_rew_mean     | -7.21    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 4360     |
# |    fps             | 46       |
# |    time_elapsed    | 4314     |
# |    total_timesteps | 198937   |
# | train/             |          |
# |    actor_loss      | 0.654    |
# |    critic_loss     | 0.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198831   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | -7.2     |
# |    success_rate    | 0.9      |
# | time/              |          |
# |    episodes        | 4364     |
# |    fps             | 46       |
# |    time_elapsed    | 4316     |
# |    total_timesteps | 199022   |
# | train/             |          |
# |    actor_loss      | 0.641    |
# |    critic_loss     | 0.0123   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198912   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.91     |
# | time/              |          |
# |    episodes        | 4368     |
# |    fps             | 46       |
# |    time_elapsed    | 4318     |
# |    total_timesteps | 199104   |
# | train/             |          |
# |    actor_loss      | 0.648    |
# |    critic_loss     | 0.0158   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 198991   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.7     |
# |    ep_rew_mean     | -7.25    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4372     |
# |    fps             | 46       |
# |    time_elapsed    | 4320     |
# |    total_timesteps | 199183   |
# | train/             |          |
# |    actor_loss      | 0.616    |
# |    critic_loss     | 0.0135   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199073   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4376     |
# |    fps             | 46       |
# |    time_elapsed    | 4321     |
# |    total_timesteps | 199255   |
# | train/             |          |
# |    actor_loss      | 0.651    |
# |    critic_loss     | 0.0117   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199151   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.6     |
# |    ep_rew_mean     | -7.23    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4380     |
# |    fps             | 46       |
# |    time_elapsed    | 4324     |
# |    total_timesteps | 199350   |
# | train/             |          |
# |    actor_loss      | 0.613    |
# |    critic_loss     | 0.00952  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199247   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -7.18    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4384     |
# |    fps             | 46       |
# |    time_elapsed    | 4325     |
# |    total_timesteps | 199426   |
# | train/             |          |
# |    actor_loss      | 0.608    |
# |    critic_loss     | 0.00785  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199317   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.2     |
# |    ep_rew_mean     | -7.19    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4388     |
# |    fps             | 46       |
# |    time_elapsed    | 4327     |
# |    total_timesteps | 199523   |
# | train/             |          |
# |    actor_loss      | 0.652    |
# |    critic_loss     | 0.0112   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199407   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.32    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4392     |
# |    fps             | 46       |
# |    time_elapsed    | 4329     |
# |    total_timesteps | 199604   |
# | train/             |          |
# |    actor_loss      | 0.65     |
# |    critic_loss     | 0.0121   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199498   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -7.37    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4396     |
# |    fps             | 46       |
# |    time_elapsed    | 4331     |
# |    total_timesteps | 199677   |
# | train/             |          |
# |    actor_loss      | 0.604    |
# |    critic_loss     | 0.0193   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199570   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.35    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4400     |
# |    fps             | 46       |
# |    time_elapsed    | 4332     |
# |    total_timesteps | 199767   |
# | train/             |          |
# |    actor_loss      | 0.657    |
# |    critic_loss     | 0.0116   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199652   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.3     |
# |    ep_rew_mean     | -7.38    |
# |    success_rate    | 0.93     |
# | time/              |          |
# |    episodes        | 4404     |
# |    fps             | 46       |
# |    time_elapsed    | 4334     |
# |    total_timesteps | 199844   |
# | train/             |          |
# |    actor_loss      | 0.657    |
# |    critic_loss     | 0.0155   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199734   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 20.4     |
# |    ep_rew_mean     | -7.46    |
# |    success_rate    | 0.92     |
# | time/              |          |
# |    episodes        | 4408     |
# |    fps             | 46       |
# |    time_elapsed    | 4337     |
# |    total_timesteps | 199939   |
# | train/             |          |
# |    actor_loss      | 0.629    |
# |    critic_loss     | 0.0188   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 199831   |
# ---------------------------------

# %%
# Load saved model
model = DDPG.load('her_ddpg_highway', env=env)
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# #### Evaluate the agent

# %%
# we use the gym >v.26 API here. Note that you could also wrap the env in a DummyVecEnv
# which allows you to use the old gym API a simplified API
obs, _ = env.reset()

# Evaluate the agent
episode_reward = 0
for _ in range(1000):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    done = truncated or terminated
    episode_reward += reward
    if done or info.get("is_success", False):
        print("Reward:", episode_reward, "Success?", info.get("is_success", False))
        episode_reward = 0.0
        obs, _ = env.reset()
# Out:
# Reward: -7.252649405517162 Success? True
# Reward: -12.512272431820186 Success? False
# Reward: -6.9715930294429596 Success? True
# Reward: -11.742236279859005 Success? False
# Reward: -6.023317212987999 Success? True
# Reward: -8.617461968026744 Success? True
# Reward: -4.495503959671879 Success? True
# Reward: -3.886870998409277 Success? True
# Reward: -7.4517091689693995 Success? True
# Reward: -5.464385185810589 Success? True
# Reward: -5.921512318985064 Success? True
# Reward: -2.7266699497834512 Success? True
# Reward: -6.892278677988796 Success? True
# Reward: -13.014264558156649 Success? False
# Reward: -8.914868693307087 Success? True
# Reward: -8.583111589178747 Success? True
# Reward: -6.8875961123554355 Success? True
# Reward: -8.55289886928479 Success? True
# Reward: -3.29278398870272 Success? True
# Reward: -5.060954916188682 Success? True
# Reward: -8.679734648327164 Success? True
# Reward: -3.6149708495630173 Success? True
# Reward: -13.45216672826766 Success? False
# Reward: -4.255882505093875 Success? True
# Reward: -5.100874574666455 Success? True
# Reward: -8.369437831669803 Success? True
# Reward: -13.086059319108086 Success? False
# Reward: -5.560402993139762 Success? True
# Reward: -3.321271217978771 Success? True
# Reward: -6.292449630327418 Success? True
# Reward: -8.96476956728232 Success? True
# Reward: -8.876828419651833 Success? True
# Reward: -6.315439595021458 Success? True
# Reward: -13.490573103816015 Success? False
# Reward: -9.353640434266945 Success? True
# Reward: -2.8217411672088923 Success? True
# Reward: -3.2895313215171558 Success? True
# Reward: -8.276416137507056 Success? True
# Reward: -5.146484725905197 Success? True
# Reward: -6.712937689052329 Success? True
# Reward: -2.884090284843005 Success? True
# Reward: -10.653114599647383 Success? False
# Reward: -8.532723350834694 Success? True
# Reward: -3.6034088343089405 Success? True
# Reward: -8.457014895841654 Success? True
# Reward: -5.65170331882845 Success? True
# Reward: -4.44291922980585 Success? True
# Reward: -9.75744421447877 Success? True
# Reward: -7.294045708785867 Success? True
# Reward: -6.046414919984677 Success? True
# Reward: -8.135271348288997 Success? True
# Reward: -6.729613421103674 Success? True
